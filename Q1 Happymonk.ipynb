# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d1 = pd.read_csv("D:/Games/archive/loan_sanction_train.csv")
d2 = pd.read_csv("D:/Games/archive_4/vgsales.csv")

# %%
d1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
d2
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 16593  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 11 columns]

# %%
from scipy.stats import lognorm

# %%
np.random.seed(1)

# %%
plt.hist(d1)
# Out:
# (array([[517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [442.,  55.,  13.,   0.,   4.,   0.,   1.,   1.,   0.,   1.],
#         [510.,   4.,   2.,   0.,   1.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.],
#         [517.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]]),
#  array([0.0, 8100.0, 16200.0, 24300.0, 32400.0, 40500.0, 48600.0, 56700.0,
#         64800.0, 72900.0, 81000.0], dtype=object),
#  <a list of 13 BarContainer objects>)

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
d1['Married']= label_encoder.fit_transform(d1['Married'])
d1['Education']= label_encoder.fit_transform(d1['Education'])
d1['Self_Employed']= label_encoder.fit_transform(d1['Self_Employed'])
d1['Property_Area']= label_encoder.fit_transform(d1['Property_Area'])
d1['Gender']= label_encoder.fit_transform(d1['Gender'])
d1['Loan_Status']= label_encoder.fit_transform(d1['Loan_Status'])

# %%
d1
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1         3+          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area  Loan_Status
# 0               1.0              2            1
# 1               1.0              0            0
# 2               1.0              2            1
# 3               1.0              2            1
# 4               1.0              2            1
# ..              ...            ...          ...
# 609             1.0              0            1
# 610             1.0              0            1
# 611             1.0              2            1
# 612             1.0              2            1
# 613             0.0              1            0
#
# [614 rows x 13 columns]

# %%
d1.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
d1 = d1.dropna()

# %%
d1
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# 5    LP001011       1        1          2          0              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1         3+          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# 5               5417             4196.0       267.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History  Property_Area  Loan_Status
# 1               1.0              0            0
# 2               1.0              2            1
# 3               1.0              2            1
# 4               1.0              2            1
# 5               1.0              2            1
# ..              ...            ...          ...
# 609             1.0              0            1
# 610             1.0              0            1
# 611             1.0              2            1
# 612             1.0              2            1
# 613             0.0              1            0
#
# [517 rows x 13 columns]

# %%
d2 = d2.drop(["Name","Platform"],axis = 1)

# %%
d2
# Out:
#         Rank    Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0          1  2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1          2  1985.0      Platform    Nintendo     29.08      3.58      6.81
# 2          3  2008.0        Racing    Nintendo     15.85     12.88      3.79
# 3          4  2009.0        Sports    Nintendo     15.75     11.01      3.28
# 4          5  1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...      ...     ...           ...         ...       ...       ...       ...
# 16593  16596  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16594  16597  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 16595  16598  2008.0        Racing  Activision      0.00      0.00      0.00
# 16596  16599  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 16597  16600  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 9 columns]

# %%
d2['Genre']= label_encoder.fit_transform(d2['Genre'])
d2['Publisher']= label_encoder.fit_transform(d2['Publisher'])

# %%
d2
# Out:
#         Rank    Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0          1  2006.0     10        359     41.49     29.02      3.77
# 1          2  1985.0      4        359     29.08      3.58      6.81
# 2          3  2008.0      6        359     15.85     12.88      3.79
# 3          4  2009.0     10        359     15.75     11.01      3.28
# 4          5  1996.0      7        359     11.27      8.89     10.22
# ...      ...     ...    ...        ...       ...       ...       ...
# 16593  16596  2002.0      4        269      0.01      0.00      0.00
# 16594  16597  2003.0      8        241      0.01      0.00      0.00
# 16595  16598  2008.0      6         21      0.00      0.00      0.00
# 16596  16599  2010.0      5          8      0.00      0.01      0.00
# 16597  16600  2003.0      4        546      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales
# 0             8.46         82.74
# 1             0.77         40.24
# 2             3.31         35.82
# 3             2.96         33.00
# 4             1.00         31.37
# ...            ...           ...
# 16593         0.00          0.01
# 16594         0.00          0.01
# 16595         0.00          0.01
# 16596         0.00          0.01
# 16597         0.00          0.01
#
# [16598 rows x 9 columns]

# %%
plt.hist(d2)
# Out:
# (array([[ 1658.,  1660.,  1660.,  1660.,  1660.,  1660.,  1660.,  1660.,
#           1659.,  1661.],
#         [    0., 16327.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.],
#         [16598.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.],
#         [16598.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.],
#         [16598.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.],
#         [16598.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.],
#         [16598.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.],
#         [16598.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.],
#         [16598.,     0.,     0.,     0.,     0.,     0.,     0.,     0.,
#              0.,     0.]]),
#  array([    0.,  1660.,  3320.,  4980.,  6640.,  8300.,  9960., 11620.,
#         13280., 14940., 16600.]),
#  <a list of 9 BarContainer objects>)

# %%
# D1 and D2 have identical Stastical Distribution. Hence, They correspond in determining the same variable.
